# %% [markdown]
# <a href="https://colab.research.google.com/github/matthewpecsok/4482_fall_2026/blob/main/tutorial/Python_and_Colab_Demonstration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is my first real notebook!

# %% [markdown]
# ## This is one plus one

# %%
1+1 # this is one plus one
# Out:
# 2

# %%
a = 10

# %% [markdown]
# ## This is five plus five!

# %%
5+5 # this is one plus one

# this is a code cell
# this is more comments
# etc
# etc
# Out:
# 10

# %%
# this is empty for now

# %%
result_one_plus_one = 1 + 1
result_one_plus_one
4+4
# Out:
# 8

# %%
'hello world!'
# Out:
# 'hello world!'

# %%
hw = 'hello world!'

# %%
float_number = 5.55555555

# %%
type(5+5.2)
# Out:
# float

# %%
a = 5
a = "hello"

# %%
a
# Out:
# 'hello'

# %%
float_number+float_number
# Out:
# 11.1111111

# %%
hw+hw
# Out:
# 'hello world!hello world!'

# %%
"hi"+"5"
# Out:
# 'hi5'

# %%
"5"+"5"
# Out:
# '55'

# %%
5+5
# Out:
# 10

# %%
some_var = "a"
other_var = "b"
another_var = "c"

# %%
str_list = ['a','b','c']

# %%
num_list = [1,2,3]

# %%
str_list[0]
# Out:
# 'a'

# %%
num_list[0]
# Out:
# 1

# %%
new_list = str_list+num_list

# %%
type(new_list[5])
# Out:
# int

# %%
type((1,2,"g"))
# Out:
# tuple

# %%
import numpy as np

# %%
np.std(num_list)
# Out:
# 0.816496580927726

# %%
import pandas as pd

# %%
my_df = pd.DataFrame({'first_name':['xiao','sumesh','matt'],
              'purchase_amount':[300.00,200.00,100.00]
              })
my_df
# Out:
#   first_name  purchase_amount
# 0       xiao            300.0
# 1     sumesh            200.0
# 2       matt            100.0

# %%
my_df.shape
# Out:
# (3, 2)

# %%
my_df.purchase_amount.sum()
# Out:
# 600.0

# %%
my_df['purchase_amount'].sum()
# Out:
# 600.0

# %%
my_df.sort_values('purchase_amount',ascending=True)
# Out:
#   first_name  purchase_amount
# 2       matt            100.0
# 1     sumesh            200.0
# 0       xiao            300.0

# %%
my_df['over_100'] = my_df['purchase_amount'] > 100
my_df
# Out:
#   first_name  purchase_amount  over_100
# 0       xiao            300.0      True
# 1     sumesh            200.0      True
# 2       matt            100.0     False

# %%
my_df[my_df['over_100']==True]
# Out:
#   first_name  purchase_amount  over_100
# 0       xiao            300.0      True
# 1     sumesh            200.0      True

# %%
my_df[my_df['over_100']==False]
# Out:
#   first_name  purchase_amount  over_100
# 2       matt            100.0     False

# %%
my_df = my_df.drop('over_100',axis=1)

# %%
my_df
# Out:
#   first_name  purchase_amount
# 0       xiao            300.0
# 1     sumesh            200.0
# 2       matt            100.0
